# %%
import numpy as np
import pandas as pd

logInfoDf = pd.read_csv("pandas_tutorial_read.csv", delimiter=';', names=['my_datetime','event','country','user_id','source','topic'])

# %%
logInfoDf.head()
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
for i, j in logInfoDf.iterrows():
    print(i,j)
    print()
# Out:
# 0 my_datetime    2018-01-01 00:01:01
# event                         read
# country                  country_7
# user_id                 2458151261
# source                         SEO
# topic                North America
# Name: 0, dtype: object
#
# 1 my_datetime    2018-01-01 00:03:20
# event                         read
# country                  country_7
# user_id                 2458151262
# source                         SEO
# topic                South America
# Name: 1, dtype: object
#
# 2 my_datetime    2018-01-01 00:04:01
# event                         read
# country                  country_7
# user_id                 2458151263
# source                     AdWords
# topic                       Africa
# Name: 2, dtype: object
#
# 3 my_datetime    2018-01-01 00:04:02
# event                         read
# country                  country_7
# user_id                 2458151264
# source                     AdWords
# topic                       Europe
# ...

# %%
j = 4
for i in logInfoDf.iterrows():
    print(i)
    print()
# Out:
# (0, my_datetime    2018-01-01 00:01:01
# event                         read
# country                  country_7
# user_id                 2458151261
# source                         SEO
# topic                North America
# Name: 0, dtype: object)
#
# (1, my_datetime    2018-01-01 00:03:20
# event                         read
# country                  country_7
# user_id                 2458151262
# source                         SEO
# topic                South America
# Name: 1, dtype: object)
#
# (2, my_datetime    2018-01-01 00:04:01
# event                         read
# country                  country_7
# user_id                 2458151263
# source                     AdWords
# topic                       Africa
# Name: 2, dtype: object)
#
# (3, my_datetime    2018-01-01 00:04:02
# event                         read
# country                  country_7
# user_id                 2458151264
# source                     AdWords
# topic                       Europe
# ...

# %%
for keys, value in logInfoDf.iteritems():
    print(keys, value)
    print()
# Out:
# 4 0       2018-01-01 00:01:01
# 1       2018-01-01 00:03:20
# 2       2018-01-01 00:04:01
# 3       2018-01-01 00:04:02
# 4       2018-01-01 00:05:03
# 5       2018-01-01 00:05:42
# 6       2018-01-01 00:06:06
# 7       2018-01-01 00:06:15
# 8       2018-01-01 00:07:21
# 9       2018-01-01 00:07:29
# 10      2018-01-01 00:07:57
# 11      2018-01-01 00:08:57
# 12      2018-01-01 00:09:11
# 13      2018-01-01 00:09:29
# 14      2018-01-01 00:11:06
# 15      2018-01-01 00:11:22
# 16      2018-01-01 00:13:05
# 17      2018-01-01 00:13:06
# 18      2018-01-01 00:13:39
# 19      2018-01-01 00:14:53
# 20      2018-01-01 00:15:44
# 21      2018-01-01 00:15:50
# 22      2018-01-01 00:17:15
# 23      2018-01-01 00:17:31
# 24      2018-01-01 00:17:58
# 25      2018-01-01 00:18:55
# 26      2018-01-01 00:20:18
# 27      2018-01-01 00:20:44
# 28      2018-01-01 00:23:16
# 29      2018-01-01 00:23:51
#                ...
# 1765    2018-01-01 23:41:11
# 1766    2018-01-01 23:41:51
# ...

# %%
logInfoDf.head(3)
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa

# %%
logInfoDf.head(5)
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
for i in logInfoDf.itertuples():
    j = 1
    while j <= 6:
        print(i[j], " ")
        j += 1
    source = i[5]
    print("the source of this one is:", source)
    print()
# Out:
# 2018-01-01 00:01:01
# read
# country_7
# 2458151261
# SEO
# North America
# the source of this one is: SEO
#
# 2018-01-01 00:03:20
# read
# country_7
# 2458151262
# SEO
# South America
# the source of this one is: SEO
#
# 2018-01-01 00:04:01
# read
# country_7
# 2458151263
# AdWords
# Africa
# the source of this one is: AdWords
#
# 2018-01-01 00:04:02
# read
# country_7
# 2458151264
# AdWords
# Europe
# the source of this one is: AdWords
#
# 2018-01-01 00:05:03
# read
# country_8
# 2458151265
# Reddit
# North America
# the source of this one is: Reddit
#
# 2018-01-01 00:05:42
# read
# country_6
# 2458151266
# Reddit
# North America
# the source of this one is: Reddit
#
# 2018-01-01 00:06:06
# read
# country_2
# 2458151267
# Reddit
# Europe
# the source of this one is: Reddit
#
# 2018-01-01 00:06:15
# read
# country_6
# 2458151268
# AdWords
# Europe
# the source of this one is: AdWords
#
# 2018-01-01 00:07:21
# read
# country_7
# 2458151269
# AdWords
# North America
# ...

# %%
columns = list(logInfoDf)

for i in columns:
    j=0
    while j < 5:
        print(logInfoDf[i][j])
        j += 1
# Out:
# ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic']
# 2018-01-01 00:01:01
# 2018-01-01 00:03:20
# 2018-01-01 00:04:01
# 2018-01-01 00:04:02
# 2018-01-01 00:05:03
# read
# read
# read
# read
# read
# country_7
# country_7
# country_7
# country_7
# country_8
# 2458151261
# 2458151262
# 2458151263
# 2458151264
# 2458151265
# SEO
# SEO
# AdWords
# AdWords
# Reddit
# North America
# South America
# Africa
# Europe
# North America

# %% [markdown]
# <h2>https://www.geeksforgeeks.org/apply-function-to-every-row-in-a-pandas-dataframe/
