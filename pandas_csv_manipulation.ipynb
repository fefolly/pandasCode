# %%
import numpy as np
import pandas as pd

logInfo = pd.read_csv("pandas_tutorial_read.csv", delimiter=';', names=['my_datetime','event','country','user_id','source','topic'])

# %%
logInfo.head()
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
logInfo.tail()
# Out:
#               my_datetime event    country     user_id   source          topic
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia

# %%
logInfo.sample(6)
# Out:
#               my_datetime event    country     user_id  source          topic
# 370   2018-01-01 04:59:54  read  country_7  2458151631  Reddit  South America
# 1170  2018-01-01 15:46:00  read  country_1  2458152431     SEO  North America
# 1145  2018-01-01 15:23:00  read  country_5  2458152406  Reddit           Asia
# 81    2018-01-01 01:15:53  read  country_7  2458151342     SEO  North America
# 1347  2018-01-01 18:17:32  read  country_2  2458152608  Reddit           Asia
# 164   2018-01-01 02:20:22  read  country_6  2458151425  Reddit           Asia

# %%
logInfo[['source','topic']]
# Out:
#        source          topic
# 0         SEO  North America
# 1         SEO  South America
# 2     AdWords         Africa
# 3     AdWords         Europe
# 4      Reddit  North America
# 5      Reddit  North America
# 6      Reddit         Europe
# 7     AdWords         Europe
# 8     AdWords  North America
# 9      Reddit  North America
# 10    AdWords           Asia
# 11        SEO      Australia
# 12     Reddit           Asia
# 13     Reddit         Europe
# 14     Reddit         Africa
# 15        SEO  North America
# 16        SEO  North America
# 17     Reddit           Asia
# 18        SEO  North America
# 19     Reddit           Asia
# 20     Reddit           Asia
# 21     Reddit         Africa
# 22    AdWords         Europe
# 23     Reddit           Asia
# 24     Reddit         Africa
# 25    AdWords  North America
# 26        SEO  North America
# 27        SEO  North America
# 28     Reddit           Asia
# 29     Reddit           Asia
# ...       ...            ...
# ...

# %%
logInfo.sample(5)[['source','topic']]
# Out:
#        source          topic
# 1791      SEO           Asia
# 310    Reddit         Europe
# 1108  AdWords           Asia
# 629   AdWords  South America
# 392    Reddit           Asia

# %%
logInfo.source =='SEO'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15       True
# 16       True
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27       True
# 28      False
# 29      False
#         ...
# 1765    False
# 1766    False
# 1767    False
# 1768    False
# 1769    False
# 1770    False
# 1771    False
# 1772     True
# 1773    False
# 1774    False
# 1775    False
# 1776    False
# 1777     True
# 1778    False
# 1779     True
# 1780    False
# 1781    False
# 1782    False
# 1783    False
# 1784     True
# 1785    False
# 1786    False
# 1787    False
# 1788    False
# 1789    False
# 1790    False
# 1791     True
# 1792    False
# 1793    False
# 1794    False
# ...

# %%
logInfo[logInfo.source == 'SEO']
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# 18    2018-01-01 00:13:39  read  country_4  2458151279    SEO  North America
# 26    2018-01-01 00:20:18  read  country_5  2458151287    SEO  North America
# 27    2018-01-01 00:20:44  read  country_2  2458151288    SEO  North America
# 30    2018-01-01 00:24:52  read  country_6  2458151291    SEO  North America
# 41    2018-01-01 00:35:23  read  country_5  2458151302    SEO           Asia
# 54    2018-01-01 00:46:42  read  country_5  2458151315    SEO  North America
# ...

# %%
logInfo.head()[['country', 'user_id']]
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
logInfo[['country', 'user_id']].head()
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %% [markdown]
# Select the user_id, the country and the topic columns for the users who are from country_2! Print the first five rows only!

# %%
logInfo[logInfo.country == 'country_2'][['user_id','topic', 'country']].head()
# Out:
#        user_id   topic    country
# 6   2458151267  Europe  country_2
# 13  2458151274  Europe  country_2
# 17  2458151278    Asia  country_2
# 19  2458151280    Asia  country_2
# 20  2458151281    Asia  country_2
