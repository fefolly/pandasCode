# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
from pandas import ExcelWriter
from pandas import ExcelFile

file = r'DurchlaufneuZN32645-.xls'
#df = pd.read_excel(file, sheetname='Sheet1' names=['Zn-Nr.','Auftrags Nr.','Serial Nr.','MSN-Nr.','Datum','Name','Bemerkung','Bemerkung','Bemerkung'])
#print(df['Occupation'])


df = pd.read_excel(file)
#df.sheet_names[u'Sheet1', u'Sheet2']
#print(df.columns)

print(df)
# Out:
#       Unnamed: 0      Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0          Fahrt             NaN        NaN        NaN           NaN
# 1         Zn-Nr.      Benennung        Name        Typ  Auftrags Nr.
# 2          32645  Rumpfbeschlag         VIL         SA     109246438
# 3          32646  Rumpfbeschlag         VAL         SA     109289413
# 4          32647  Rumpfbeschlag         MAL         SA     109246492
# 5          32648  Rumpfbeschlag         MIL         SA     109236287
# 6          32649  Rumpfbeschlag         VIL         SA     109246442
# 7          32650  Rumpfbeschlag         VAL         SA     109289418
# 8          32651  Rumpfbeschlag         MAL         SA     109246499
# 9          32652  Rumpfbeschlag         MIL         SA     109236282
# 10         32653  Rumpfbeschlag         VIR         SA     109246558
# 11         32654  Rumpfbeschlag         VAR         SA     109291429
# 12         32655  Rumpfbeschlag         MAR         SA     109246633
# ...
